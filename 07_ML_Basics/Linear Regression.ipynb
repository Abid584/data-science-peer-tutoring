# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
advertising = pd.read_csv( "/content/drive/MyDrive/Colab Notebooks/advertising.csv" )
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# Let us plot the scatter plot for target variable vs. predictor variables in a single plot to get the intuition. Also, plotting a heatmap for all the variable

# %%
sns.pairplot(advertising, x_vars=[ 'TV', 'Newspaper','Radio' ], y_vars = 'Sales', height = 4, kind = 'scatter' )
plt.show()

# %%
sns.heatmap( advertising.corr(), annot = True )
plt.show()

# %% [markdown]
# From the scatterplot and the heatmap, we can observe that ‘Sales’ and ‘TV’ have a higher correlation as compared to others because it shows a linear pattern in the scatterplot as well as giving 0.9 correlation.

# %%
X = advertising[ 'TV' ]
y = advertising[ 'Sales' ]

# %% [markdown]
# And after assigning the variables you need to split our variable into training and testing sets. You’ll perform this by importing train_test_split from the sklearn.model_selection library. It is usually a good practice to keep 70% of the data in your train dataset and the rest 30% in your test dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, train_size = 0.7, test_size = 0.3, random_state = 42)

# %%
type(X_test)
# X_test.shape
# Out:
# numpy.ndarray

# %%
X_train = X_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)

# %%
print( X_train.shape )
print( X_test.shape )
print( y_train.shape )
print( y_test.shape )
# Out:
# (140, 1)
# (60, 1)
# (140, 1)
# (60, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

# %%
# y_pred_test

# %%
# Prediction on test set
plt.scatter(X_test, y_test, color = 'lightcoral')
plt.plot(X_train,y_pred_train, color = 'firebrick')
plt.title('Tv vs Sale  (Test Set)')
plt.xlabel('TV')
plt.ylabel('Sale')
plt.legend(['X_test/Pred(y_test)', 'X_train/y_train'], title = 'TV/Sale', facecolor='white')
plt.box(False)
plt.show()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred_test)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 81.0%

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
score = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("The Mean Squared Error of our Model is {}".format(round(score, 2)))
# Out:
# The Mean Squared Error of our Model is 2.28

# %%
a=np.array([500])
a=a.reshape(-1,1)

# %%
a.shape
# Out:
# (1, 1)

# %%
y_pred_test2 = regressor.predict(a)

# %%
y_pred_test2
# Out:
# array([[34.62399645]])

# %% [markdown]
# Exam Question

# %%
X = np.array([2, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# %%
# model = LinearRegression()

# %%
model = LinearRegression().fit(X, y)

# %%
y_pred_test = model.predict(X)

# %%
y_pred_test
# Out:
# array([3.4, 2.8, 5.2, 4.6, 4. ])

# %%
X = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# %%
# Prediction on test set
plt.scatter(X, y, color = 'lightcoral')
plt.plot(X,y_pred_test, color = 'firebrick')
plt.title('Tv vs Sale  (Test Set)')
plt.xlabel('TV')
plt.ylabel('Sale')
plt.legend(['X_test/Pred(y_test)', 'X_train/y_train'], title = 'TV/Sale', facecolor='white')
plt.box(False)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
score = np.sqrt(mean_squared_error(y, y_pred_test))
print("The Mean Squared Error of our Model is {}".format(round(score, 2)))
# Out:
# The Mean Squared Error of our Model is 5.81

# %%
X = np.array([43, 21, 25, 42, 57, 59]).reshape((-1, 1))
y = np.array([99, 65, 79, 75 ,87, 81])

# %%
model = LinearRegression().fit(X, y)

# %%
a=np.array([55])
a=a.reshape(-1,1)

# %%
y_pred_test = model.predict(a)

# %%
y_pred_test
# Out:
# array([86.3289456])

# %%
y_pred_test = model.predict(X)

# %%
X = np.array([43, 21, 25, 42, 57, 59]).reshape((-1, 1))
y = np.array([99, 65, 79, 75 ,87, 81])

# %%
# Prediction on test set
plt.scatter(X, y, color = 'lightcoral')
plt.plot(X,y_pred_test, color = 'firebrick')
plt.title('Tv vs Sale  (Test Set)')
plt.xlabel('TV')
plt.ylabel('Sale')
plt.legend(['X_test/Pred(y_test)', 'X_train/y_train'], title = 'TV/Sale', facecolor='white')
plt.grid()
plt.box(False)
plt.show()
